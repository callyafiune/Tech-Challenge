# %% [markdown]
# # EDA - Telco Churn
#
# Notebook de apoio para exploração do dataset e geração dos artefatos de EDA.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from tech_challenge_churn.data.load import read_raw_data
from tech_challenge_churn.data.schema import validate_telco_schema

data = validate_telco_schema(read_raw_data(PROJECT_ROOT / "Telco-Customer-Churn.csv"))
data.head()

# %%
data["Churn"].value_counts(normalize=True).rename("proporcao")

# %%
from tech_challenge_churn.reports.eda import generate_eda_report

generate_eda_report()

# %% [markdown]
# Para treinar os baselines e registrar no MLflow, execute no terminal:
#
# ```powershell
# .\.venv\Scripts\python.exe -m tech_challenge_churn.models.baselines
# ```
